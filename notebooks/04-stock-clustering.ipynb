# %% [markdown]
# HBDscan
# {
# 1 : [10, 21, 27, 32, 37, 44, 69, 83, 85, 110, 111, 112]
# 2 : [2, 7, 13, 14, 15, 17, 19, 20, 23, 26, 29, 30, 34, 35, 36, 39, 41, 42, 43, 46, 47, 48, 51, 52, 53, 64, 67, 68, 70, 93, 95, 102, 103, 104, 105, 107, 109, 113, 114, 115, 119, 120, 123, 125]
# 3 : [3, 6, 8, 9, 18, 61, 63, 75, 80, 81, 86, 89, 90, 97]
# 4 : [1, 11, 22, 50, 55, 56, 62, 73, 76, 78, 84, 87, 96, 101, 116, 122, 124, 126]
# 5 : [0, 4, 5, 16, 28, 33, 66, 72, 94, 100, 108, 118]
# 6 : [31, 38, 40, 58, 59, 60, 74, 77, 82, 88, 98, 99]
# }

# %% [markdown]
# NearestNeighbors 5
# {
# 0 : [0, 15, 17, 102, 104],
# 1 : [1, 87, 23, 101, 11],
# 2 : [2, 125, 93, 41, 123],
# 3 : [3, 97, 6, 62, 55],
# 4 : [4, 17, 102, 15, 0],
# 5 : [5, 22, 118, 23, 56],
# 6 : [6, 3, 97, 75, 27],
# 7 : [7, 95, 52, 35, 36],
# 8 : [8, 1, 101, 87, 122],
# 9 : [9, 78, 126, 55, 22],
# 10 : [10, 44, 95, 15, 26],
# 11 : [11, 87, 1, 23, 56],
# 13 : [13, 51, 93, 123, 14],
# 14 : [14, 32, 13, 67, 123],
# 15 : [15, 26, 95, 10, 44],
# 16 : [16, 17, 15, 109, 102],
# 17 : [17, 102, 73, 15, 114],
# 18 : [18, 6, 75, 97, 27],
# 19 : [19, 20, 67, 70, 51],
# 20 : [20, 67, 53, 34, 14],
# 21 : [21, 123, 93, 47, 67],
# 22 : [22, 73, 56, 102, 23],
# 23 : [23, 102, 73, 17, 1],
# 26 : [26, 95, 20, 67, 15],
# 27 : [27, 62, 33, 112, 97],
# 28 : [28, 67, 120, 95, 51],
# 29 : [29, 43, 46, 125, 41],
# 30 : [30, 17, 15, 104, 66],
# 31 : [31, 119, 108, 104, 35],
# 32 : [32, 14, 108, 13, 119],
# 33 : [33, 5, 112, 126, 103],
# 34 : [34, 93, 123, 67, 2],
# 35 : [35, 14, 119, 32, 67],
# 36 : [36, 95, 26, 44, 48],
# 37 : [37, 27, 62, 40, 97],
# 38 : [38, 23, 102, 4, 118],
# 39 : [39, 67, 51, 2, 34],
# 40 : [40, 118, 5, 112, 22],
# 41 : [41, 125, 46, 47, 29],
# 42 : [42, 95, 104, 20, 52],
# 43 : [43, 29, 46, 125, 41],
# 44 : [44, 95, 10, 26, 15],
# 46 : [46, 125, 41, 29, 47],
# 47 : [47, 41, 125, 46, 93],
# 48 : [48, 120, 95, 35, 104],
# 50 : [50, 95, 120, 36, 115],
# 51 : [51, 13, 67, 123, 93],
# 52 : [52, 20, 95, 67, 107],
# 53 : [53, 20, 34, 67, 120],
# 55 : [55, 22, 56, 116, 73],
# 56 : [56, 113, 73, 96, 23],
# 58 : [58, 59, 104, 48, 0],
# 59 : [59, 104, 48, 42, 95],
# 60 : [60, 48, 95, 104, 26],
# 61 : [61, 73, 124, 113, 96],
# 62 : [62, 126, 87, 112, 55],
# 63 : [63, 50, 36, 95, 48],
# 64 : [64, 93, 69, 47, 123],
# 66 : [66, 15, 95, 52, 72],
# 67 : [67, 51, 123, 105, 14],
# 68 : [68, 20, 39, 67, 107],
# 69 : [69, 29, 41, 93, 47],
# 70 : [70, 67, 14, 51, 20],
# 72 : [72, 52, 95, 20, 107],
# 73 : [73, 113, 76, 84, 102],
# 74 : [74, 119, 48, 35, 44],
# 75 : [75, 97, 6, 3, 27],
# 76 : [76, 73, 113, 102, 17],
# 77 : [77, 120, 35, 32, 14],
# 78 : [78, 56, 22, 73, 96],
# 80 : [80, 97, 6, 75, 3],
# 81 : [81, 78, 55, 9, 126],
# 82 : [82, 35, 48, 104, 15],
# 83 : [83, 109, 116, 102, 73],
# 84 : [84, 122, 73, 36, 50],
# 85 : [85, 14, 32, 35, 120],
# 86 : [86, 120, 115, 69, 53],
# 87 : [87, 1, 23, 11, 56],
# 88 : [88, 22, 5, 118, 102],
# 89 : [89, 44, 26, 95, 48],
# 90 : [90, 87, 56, 126, 116],
# 93 : [93, 47, 13, 2, 46],
# 94 : [94, 109, 17, 15, 73],
# 95 : [95, 26, 52, 20, 120],
# 96 : [96, 56, 61, 73, 113],
# 97 : [97, 3, 9, 62, 6],
# 98 : [98, 114, 102, 23, 17],
# 99 : [99, 123, 47, 41, 13],
# 100 : [100, 94, 109, 22, 23],
# 101 : [101, 122, 84, 1, 109],
# 102 : [102, 73, 17, 23, 113],
# 103 : [103, 114, 23, 118, 5],
# 104 : [104, 107, 95, 26, 70],
# 105 : [105, 67, 123, 93, 34],
# 107 : [107, 104, 20, 52, 70],
# 108 : [108, 32, 119, 14, 35],
# 109 : [109, 94, 17, 15, 73],
# 110 : [110, 23, 56, 113, 1],
# 111 : [111, 123, 47, 67, 41],
# 112 : [112, 22, 126, 116, 55],
# 113 : [113, 73, 56, 102, 61],
# 114 : [114, 17, 109, 102, 0],
# 115 : [115, 67, 53, 20, 120],
# 116 : [116, 73, 56, 102, 113],
# 118 : [118, 102, 22, 23, 113],
# 119 : [119, 14, 108, 32, 35],
# 120 : [120, 67, 14, 32, 53],
# 122 : [122, 84, 36, 73, 95],
# 123 : [123, 13, 93, 67, 51],
# 124 : [124, 61, 36, 44, 73],
# 125 : [125, 46, 41, 47, 29],
# 126 : [126, 62, 87, 1, 56]
# }

# %% [markdown]
# KMeans 7
#
# {
# 1 : [1, 11, 22, 50, 55, 56, 62, 73, 76, 78, 84, 87, 96, 101, 112, 116, 122, 124, 126]
# 2 : [0, 4, 5, 10, 15, 16, 17, 23, 26, 28, 29, 36, 42, 44, 48, 53, 66, 69, 72, 85, 94, 95, 100, 102, 109, 111, 113, 115, 118, 120]
# 3 : [3, 6, 9, 18, 61, 63, 86, 97]
# 4 : [27, 31, 33, 37, 38, 40, 58, 59, 60, 74, 75, 77, 82, 83, 88, 89, 90, 98, 99, 110]
# 5 : [2, 7, 13, 14, 19, 20, 21, 30, 32, 34, 35, 39, 41, 43, 46, 47, 51, 52, 64, 67, 68, 70, 93, 103, 104, 105, 107, 108, 114, 119, 123, 125]
# 6 : [81]
# 7 : [8, 80]
# }

# %% [markdown]
# Hamiltonian Equity type
# {
# 1 : [29, 69, 124, 43, 50, 44, 14, 111, 56] # "Index Funds"
# 2 : [1, 10, 36, 123, 39, 41, 99, 32, 35, 108, 119, 2, 93, 125, 13, 51, 6, 63, 81, 61, 84, 120, 17, 20, 26, 28, 34, 42, 47, 48, 52, 62, 64, 67, 70, 73, 76, 77, 80, 85, 86, 95, 96, 100, 101, 109, 113, 122, 46, 8, 15] # "Heavily Traded Equities"
# 3 : [0,3,4,5,7,9,11,16,18,19,21,22,23,27,30,31,33,37,38,40,53,55,58,59,60,66,68,72,74,75,78,82,83,87,88,89,90,94,97,98,102,103,104,105,107,110,112,114,115,116,118,126)] # "Low Volume Equities"
# }

# %% [markdown]
# ## Time, HBD (447 columns)
#
# Training fold 1
#
# Fold 1: R2 score: 0.807, RMSPE: 0.224
#
# Training fold 2
#
# Fold 2: R2 score: 0.814, RMSPE: 0.233
#
# Training fold 3
#
# Fold 3: R2 score: 0.825, RMSPE: 0.22
#
# Training fold 4
#
# Fold 4: R2 score: 0.806, RMSPE: 0.218
#
# Training fold 5
#
# Fold 5: R2 score: 0.824, RMSPE: 0.216
#
# OOF: R2 score: 0.815, RMSPE: 0.222

# %%
modelCols = ['real_vol1',
 'real_vol4',
 'OB_wap2_dollar_change_abs_sum',
 'real_vol2',
 'real_vol3',
 'OB_wap4_dollar_change_abs_sum',
 'time_num_seconds_norm_mean_time',
 'price_spread_sum',
 'OB_wap1_dollar_change_abs_sum_mean_stock',
 'time_num_seconds_norm_std_time',
 'OB_wap1_MA10_MA20_num_cross_mean_time',
 'spread_sum',
 'real_vol1_mean_stock',
 'price_spread_sum_min_time',
 'real_vol2_min_time_kmn7',
 'spread2_max_400',
 'volume_imbalance_min',
 'time_num_seconds_norm_min_time',
 'real_vol3_min_time_kmn7',
 'real_vol2_min_time',
 'market_cap_volume_std_mean_time',
 'wap1_std',
 'bid_ask_diff_wap2_ratio_mean_min_time',
 'bid_ask_diff_wap2_ratio_mean',
 'bid_ask_diff_wap2_ratio_mean_std_time',
 'bid_ask_diff_sum',
 'wapbal_sum',
 'real_vol3_mean_stock',
 'bid_ask_diff_wap2_ratio_mean_mean_time',
 'market_cap_volume_std_min_time',
 'market_cap_volume_max_mean_time',
 'volume_imbalance_min_400',
 'price_spread_sum_mean_stock',
 'real_vol4_mean_stock',
 'OB_wap1_dollar_change_abs_sum',
 'real_vol2_min_time_hbd',
 'real_vol2_std_time',
 'OB_wap1_dollar_change_abs_sum_mean_time_hbd',
 'spread2_max_300',
 'real_vol3_min_time',
 'real_vol1_min_stock',
 'real_vol2_300',
 'wap1_std_std_time',
 'volume_imbalance_min_300',
 'real_vol4_std_time',
 'bid_ask_spread_max_300',
 'OB_wap1_dollar_change_abs_sum_std_time',
 'real_vol1_min_time',
 'real_vol1_400',
 'OB_wap1_dollar_change_abs_sum_mean_time_kmn7',
 'market_cap_volume_max_min_time',
 'OB_wap1_MA10_MA20_num_cross_std_time',
 'OB_wap1_MA10_MA20_num_cross_min_time',
 'price_spread_sum_mean_time',
 'spread2_max_500',
 'real_vol1_300',
 'price_spread_sum_max_time',
 'bid_ask_spread_max_500',
 'real_vol1_min_time_hbd',
 'OB_wap1_dollar_change_abs_sum_min_time_kmn7',
 'spread2_max',
 'real_vol2_mean_stock',
 'real_vol2_400',
 'real_vol2_min_time_eqtyp',
 'wap1_std_mean_stock',
 'OB_wap1_dollar_change_abs_sum_min_time',
 'market_cap_volume_std_max_time',
 'real_vol2_mean_time',
 'bid_ask_spread_max_400',
 'real_vol2_mean_time_kmn7',
 'bid_ask_diff_wap2_ratio_mean_max_time',
 'real_vol3_std_time',
 'real_vol4_min_time',
 'wap1_std_mean_time',
 'real_vol1_std_time',
 'spread_max_500',
 'real_vol1_min_time_kmn7',
 'market_cap_volume_max_max_time',
 'wap1_std_max_time',
 'real_vol4_max_time',
 'real_vol4_min_stock',
 'real_vol1_500',
 'total_volume_max_400',
 'wap1_std_min_time',
 'price_spread_sum_std_stock',
 'bid_ask_spread_max',
 'time_num_seconds_norm_min_time_hbd',
 'market_cap_volume_std_std_time',
 'market_cap_volume_max_std_time',
 'real_vol1_max_time',
 'bid_ask_diff_wap2_ratio_mean_min_time_eqtyp',
 'real_vol3_max_time',
 'OB_wap1_dollar_change_abs_sum_max_time',
 'volume_imbalance_max_400',
 'real_vol1_std_stock',
 'spread_max',
 'real_vol4_mean_time',
 'wap1_std_mean_time_hbd',
 'price_spread_sum_std_time',
 'real_vol1_mean_time_hbd',
 'real_vol1_mean_time',
 'OB_wap1_MA10_MA20_num_cross_max_time',
 'OB_wap1_dollar_change_abs_sum_min_stock',
 'price_spread_sum_mean_time_kmn7',
 'OB_ask_price1_dollar_change_abs_std_300',
 'real_vol2_max_time',
 'real_vol1_mean_time_kmn7',
 'volume_imbalance_min_500',
 'volume_imbalance_max_300',
 'real_vol3_mean_time',
 'OB_wap1_dollar_change_abs_sum_mean_time',
 'real_vol2_min_stock',
 'orderSize_to_totalbook_shift_std',
 'wap1_std_min_stock',
 'market_cap_volume_max',
 'time_num_seconds_norm_max_time',
 'volume_imbalance_max_500',
 'bid_ask_diff_wap2_ratio_mean_300',
 'price_spread_sum_min_time_eqtyp',
 'real_vol3_min_time_hbd',
 'wapbal_sum_500',
 'real_vol3_400',
 'wap1_std_mean_time_kmn7',
 'OB_wap4_dollar_change_abs_sum_300',
 'bid_ask_diff_wap2_ratio_mean_500',
 'OB_bid_price1_dollar_change_min_300',
 'wap1_std_500',
 'time_num_seconds_norm_min_time_eqtyp',
 'total_volume_max',
 'real_vol2_mean_time_hbd',
 'OB_ask_price1_dollar_change_abs_std_400',
 'OB_wap2_dollar_change_abs_sum_300',
 'market_cap_volume_std_mean_time_eqtyp',
 'OB_wap1_dollar_change_abs_sum_std_stock',
 'real_vol4_400',
 'real_vol2_std_stock',
 'total_volume_max_500',
 'market_cap_volume_std',
 'market_cap_volume_std_mean_stock',
 'wap1_std_mean_time_eqtyp',
 'price_spread_sum_min_time_hbd',
 'bid_ask_diff_wap2_ratio_mean_400',
 'time_num_seconds_norm_mean_time_hbd',
 'price_spread_sum_mean_time_eqtyp',
 'wapbal_sum_400',
 'real_vol1_min_time_eqtyp',
 'real_vol3_std_stock']

# %% [markdown]
# ## ALL + Public1

# %% [markdown]
# Fold 1: R2 score: 0.814, RMSPE: 0.22
#
# Fold 2: R2 score: 0.823, RMSPE: 0.227
#
# Fold 3: R2 score: 0.829, RMSPE: 0.215
#
# Fold 4: R2 score: 0.819, RMSPE: 0.213
#
# Fold 5: R2 score: 0.831, RMSPE: 0.211
#
# OOF: R2 score: 0.823, RMSPE: 0.217

# %%
['book_log_return1_realized_absvar',
 'real_vol1',
 'book_log_return1_realized_volatility_150win_150',
 'book_log_return1_realized_absvar_150win_150',
 'book_log_return2_realized_absvar',
 'book_log_return2_realized_volatility_150win_150',
 'stock_id',
 'book_log_return1_realized_absvar_150win_300',
 'book_log_return2_realized_absvar_150win_150',
 'real_vol4',
 'real_vol2',
 'book_log_return2_realized_absvar_150win_300',
 'book_log_return2_realized_volatility_150win_450',
 'book_log_return1_realized_volatility_150win_450',
 'bid_ask_diff_sum',
 'time_num_seconds_norm_mean_time',
 'time_num_seconds_norm_300_mean_time',
 'time_num_seconds_norm_std_time',
 'book_price_spread_sum_150win_450',
 'OB_wap1_MA10_MA20_num_cross_mean_time',
 'trade_log_return_realized_absvar',
 'market_cap_volume_sum_min_time',
 'real_vol3',
 'trade_log_return_realized_absvar_150win_450',
 'wapbal_sum',
 'trade_log_return_realized_absvar_150win_300',
 'book_price_spread_sum_150win_150',
 'bid_ask_diff_wap2_ratio_mean_300_min_time',
 'OB_wap1_dollar_change_abs_sum_mean_stock',
 'market_cap_volume_sum_300_min_time',
 'real_vol2_300_min_time',
 'volume_imbalance_min',
 'market_cap_volume_sum_mean_time',
 'price_spread_sum_300_min_time',
 'bid_ask_diff_wap2_ratio_mean_min_time',
 'bid_ask_diff_wap2_ratio_mean_mean_time',
 'time_num_seconds_norm_min_time',
 'real_vol2_min_time_kmn7',
 'real_vol1_300_min_time_kmn7',
 'market_cap_volume_sum_300_std_stock',
 'real_vol2_min_time_hbd',
 'book_dispersion_sum_150win_300',
 'market_cap_volume_sum_300_mean_time',
 'book_log_return2_realized_absvar_150win_450',
 'trade_log_return_realized_volatility_150win_450',
 'real_vol3_min_time_kmn7',
 'time_num_seconds_norm_300_std_time',
 'market_cap_volume_sum_mean_stock',
 'bid_ask_diff_wap2_ratio_mean',
 'real_vol2_std_time',
 'real_vol2_mean_stock',
 'bid_ask_diff_wap2_ratio_mean_std_time',
 'real_vol2_300_min_time_eqtyp',
 'bid_ask_diff_wap2_ratio_mean_500',
 'real_vol4_std_time',
 'book_dispersion_sum_150win_150',
 'wap1_std_300_mean_time',
 'bid_ask_spread_max_400',
 'real_vol2_mean_time_kmn7',
 'spread2_max_300',
 'time_num_seconds_norm_300_min_time',
 'OB_wap1_dollar_change_abs_sum_std_time',
 'market_cap_volume_sum_std_time',
 'wap1_std_std_time',
 'bid_ask_diff_wap2_ratio_mean_300_mean_time',
 'OB_wap1_dollar_change_abs_sum_300_mean_time_kmn7',
 'real_vol2_300',
 'real_vol2_min_time',
 'price_spread_sum_300_min_time_eqtyp',
 'OB_wap1_MA10_MA20_num_cross_std_time',
 'market_cap_volume_sum_max_time',
 'price_spread_sum_300_mean_time',
 'OB_wap1_MA10_MA20_num_cross_300_std_time',
 'real_vol4_300_min_time',
 'real_vol3_300_min_time_kmn7',
 'real_vol2_300_min_time_kmn7',
 'OB_wap1_MA10_MA20_num_cross_min_time',
 'trade_log_return_realized_volatility',
 'OB_wap1_MA10_MA20_num_cross_300_mean_time',
 'market_cap_volume_sum_300_max_time',
 'real_vol1_300_min_time',
 'bid_ask_diff_wap2_ratio_mean_300_std_time',
 'wap1_std_300_mean_time_kmn7',
 'real_vol3_300_min_time',
 'OB_wap1_dollar_change_abs_sum_300_mean_time_hbd',
 'wap1_std_300_std_time',
 'real_vol3_std_time',
 'price_spread_sum_300_max_time',
 'spread2_max_400',
 'price_spread_sum_mean_time',
 'OB_wap1_dollar_change_abs_sum_min_time',
 'OB_wap1_dollar_change_abs_sum_300_mean_time',
 'real_vol3_min_time',
 'OB_wap1_dollar_change_abs_sum_300_min_time',
 'price_spread_sum_max_time',
 'wap1_std_max_time',
 'OB_wap1_dollar_change_abs_sum_300_min_time_kmn7',
 'real_vol1_500',
 'bid_ask_diff_wap2_ratio_mean_max_time',
 'real_vol4_max_time',
 'real_vol1_min_time_hbd',
 'spread2_max_500',
 'real_vol1_min_stock',
 'market_cap_volume_sum_300_std_time',
 'real_vol1_std_time',
 'bid_ask_spread_max_300',
 'bid_ask_diff_wap2_ratio_mean_300_max_time',
 'wap1_std_300_max_time',
 'real_vol1_300_mean_time',
 'bid_ask_diff_wap2_ratio_mean_300_min_time_eqtyp',
 'real_vol1_min_time',
 'real_vol3_300_std_time',
 'price_spread_sum_mean_time_kmn7',
 'real_vol4_min_time',
 'real_vol1_400',
 'wap1_std_300_min_time',
 'spread_max_500',
 'OB_wap1_dollar_change_abs_sum_max_time',
 'trade_log_return_realized_absvar_150win_150',
 'OB_wap2_dollar_change_abs_sum',
 'OB_wap1_MA10_MA20_num_cross_max_time',
 'real_vol4_300_std_time',
 'real_vol2_300_min_time_hbd',
 'real_vol4_300_max_time',
 'OB_wap1_dollar_change_abs_sum_std_stock',
 'wap1_std_mean_time',
 'wap1_std_min_time',
 'bid_ask_diff_wap2_ratio_mean_300',
 'OB_wap1_dollar_change_abs_sum_mean_time_kmn7',
 'real_vol1_300',
 'real_vol3_300_min_time_eqtyp',
 'real_vol1_300_max_time',
 'market_cap_volume_sum_300_min_time_hbd',
 'real_vol3_300_max_time',
 'OB_wap1_dollar_change_abs_sum_300_std_time',
 'spread2_max',
 'real_vol1_300_std_time',
 'OB_wap1_dollar_change_abs_sum_mean_time_hbd',
 'real_vol1_max_time',
 'real_vol2_max_time',
 'book_log_return1_realized_absvar_150win_450',
 'OB_wap1_dollar_change_abs_sum_mean_time',
 'volume_imbalance_max_500',
 'price_spread_sum_300_std_time',
 'OB_wap1_dollar_change_abs_sum_300_max_time',
 'real_vol2_mean_time',
 'real_vol2_300_std_time',
 'real_vol4_mean_time',
 'price_spread_sum_std_time',
 'price_spread_sum_300_mean_time_kmn7',
 'real_vol2_300_max_time',
 'real_vol1_min_time_kmn7',
 'time_num_seconds_norm_max_time',
 'real_vol3_max_time',
 'OB_wap1_dollar_change_abs_sum_min_time_eqtyp',
 'wap1_std_mean_stock',
 'price_spread_sum_std_stock',
 'real_vol1_mean_time_kmn7',
 'price_spread_sum_mean_time_hbd',
 'price_spread_sum_mean_time_eqtyp',
 'real_vol3_300_mean_time',
 'bid_ask_diff_wap2_ratio_mean_min_time_eqtyp',
 'spread_max',
 'bid_ask_diff_wap2_ratio_mean_mean_stock',
 'real_vol4_300_mean_time',
 'volume_imbalance_min_400',
 'real_vol3_mean_time',
 'real_vol2_300_mean_time',
 'volume_imbalance_min_300',
 'real_vol2_min_time_eqtyp',
 'OB_wap4_dollar_change_abs_sum_400',
 'volume_imbalance_min_500',
 'book_depth_sum',
 'OB_wap1_dollar_change_abs_sum',
 'trade_log_return_realized_volatility_150win_300',
 'trade_order_count_amax',
 'real_vol1_mean_time',
 'wap1_std',
 'bid_ask_spread_max',
 'real_vol2_mean_time_hbd',
 'OB_wap1_MA10_MA20_num_cross_300_max_time',
 'time_num_seconds_norm_min_time_eqtyp',
 'bid_ask_spread_max_500',
 'OB_wap1_dollar_change_abs_sum_300',
 'real_vol4_300_min_time_eqtyp',
 'trade_order_count_sum_150win_450',
 'OB_wap1_dollar_change_abs_sum_min_time_kmn7',
 'real_vol3_min_time_hbd',
 'book_depth_sum_150win_150',
 'market_cap_volume_sum_min_time_kmn7',
 'real_vol4_min_time_kmn7',
 'OB_bid_price1_dollar_change_min_300',
 'trade_size_tau_150win_450',
 'real_vol1_std_stock',
 'OB_wap1_MA10_MA20_num_cross_300_min_time',
 'price_spread_sum_min_time_eqtyp',
 'real_vol3_std_stock',
 'wapbal_sum_300',
 'OB_wap4_dollar_change_abs_sum',
 'real_vol4_300_min_time_kmn7',
 'wapbal_sum_400',
 'real_vol3_300_mean_time_kmn7',
 'market_cap_volume_max',
 'OB_wap2_dollar_change_abs_sum_300',
 'trade_log_return_realized_volatility_150win_150',
 'market_cap_volume_sum',
 'time_num_seconds_norm_min_time_hbd',
 'wap1_std_mean_time_hbd',
 'market_cap_volume_sum_std_time_eqtyp',
 'wapbal_sum_500',
 'real_vol1_mean_time_hbd',
 'trade_price_wap1_num_cross',
 'market_cap_volume_sum_std_stock',
 'trade_size_tau_150win_300',
 'OB_wap1_dollar_change_abs_sum_300_min_time_hbd',
 'wap1_std_300_mean_time_eqtyp',
 'book_depth_sum_150win_300',
 'market_cap_volume_sum_mean_time_eqtyp',
 'real_vol4_400',
 'OB_wap1_MA20_above_MA50_sum',
 'market_cap_volume_sum_min_time_hbd',
 'real_vol4_min_stock',
 'market_cap_volume_std',
 'price_spread_sum_300_max_time_eqtyp',
 'total_volume_max_400',
 'time_num_seconds_norm_300_min_time_hbd',
 'bid_ask_diff_sum_300',
 'OB_wap1_dollar_change_abs_sum_std_time_eqtyp',
 'real_vol1_300_min_time_hbd',
 'real_vol3_300_min_time_hbd',
 'bid_ask_diff_wap2_ratio_mean_mean_time_eqtyp']

# %% [markdown]
# # Public 2
#
# Default params
#
# Training fold 1
#
# Fold 1: R2 score: 0.826, RMSPE: 0.218
#
# Fold 2: R2 score: 0.823, RMSPE: 0.231
#
# Fold 3: R2 score: 0.831, RMSPE: 0.214
#
# Fold 4: R2 score: 0.815, RMSPE: 0.215
#
# Fold 5: R2 score: 0.833, RMSPE: 0.21
#
# OOF: R2 score: 0.826, RMSPE: 0.218
#
# --------------------------------------------
#
# Public notebook params 1
#
# Fold 1: R2 score: 0.823, RMSPE: 0.217
#
# Fold 2: R2 score: 0.826, RMSPE: 0.23
#
# Fold 3: R2 score: 0.838, RMSPE: 0.213
#
# Fold 4: R2 score: 0.816, RMSPE: 0.213
#
# Fold 5: R2 score: 0.827, RMSPE: 0.211
#
# OOF: R2 score: 0.826, RMSPE: 0.217
#
# ________________________________________________
#
# Public notebook params 2
#
# ???

# %% [markdown]
# # Illi (126) + Public1 (128) + Public2 (All)
#
# ## GroupKFold
#
# Public notebook params 1
#
# Fold 1: R2 score: 0.826, RMSPE: 0.216
#
# Fold 2: R2 score: 0.825, RMSPE: 0.226
#
# Fold 3: R2 score: 0.835, RMSPE: 0.212
#
# Fold 4: R2 score: 0.82, RMSPE: 0.213
#
# Fold 5: R2 score: 0.839, RMSPE: 0.207
#
# OOF: R2 score: 0.829, RMSPE: 0.215
#
#
# -----------------------------------
#
# Public notebook params 2
#
# Fold 1: R2 score: 0.817, RMSPE: 0.219
#
# Fold 2: R2 score: 0.828, RMSPE: 0.225
#
# Fold 3: R2 score: 0.839, RMSPE: 0.213
#
# Fold 4: R2 score: 0.821, RMSPE: 0.212
#
# Fold 5: R2 score: 0.837, RMSPE: 0.209
#
# OOF: R2 score: 0.828, RMSPE: 0.216
#
# -----------------------------
#
# ## KFold
#
# Tuned params
#
# seed0=2021
# params0 = {
#     'objective': 'rmse',
#     'boosting_type': 'gbdt',
#     'max_depth': 5,
#     'max_bin':100,
#     'min_data_in_leaf':500,
#     'learning_rate': 0.05,
#     'subsample': 0.7,
#     'subsample_freq': 4,
#     'feature_fraction': 0.5,
#     'lambda_l1': 0.5,
#     'lambda_l2': 10,
#     'categorical_column':[0],
#     'seed':seed0,
#     'feature_fraction_seed': seed0,
#     'bagging_seed': seed0,
#     'drop_seed': seed0,
#     'data_random_seed': seed0,
#     'n_jobs':-1,
#     'verbose': -1}
#
#
# Fold 1: R2 score: 0.869, RMSPE: 0.189
#
# Fold 2: R2 score: 0.866, RMSPE: 0.185
#
# Fold 3: R2 score: 0.864, RMSPE: 0.2
#
# Fold 4: R2 score: 0.872, RMSPE: 0.188
#
# Fold 5: R2 score: 0.86, RMSPE: 0.191
#
# OOF: R2 score: 0.866, RMSPE: 0.191

# %%
def pickle_dump(path, saveobj):
    import pickle
    filehandler = open(path,"wb")
    pickle.dump(saveobj,filehandler)
    print("File pickled")
    filehandler.close()

# %%
illiCols = ['real_vol1',
 'real_vol4',
 'real_vol2',
 'OB_wap2_dollar_change_abs_sum',
 'real_vol3',
 'OB_wap4_dollar_change_abs_sum',
 'OB_wap1_dollar_change_abs_sum',
 'OB_wap1_dollar_change_abs_sum_mean_stock',
 'spread_sum',
 'time_num_seconds_norm_mean_time',
 'time_num_seconds_norm_300_mean_time',
 'real_vol2_mean_stock',
 'time_num_seconds_norm_std_time',
 'wapbal_sum',
 'OB_wap1_MA10_MA20_num_cross_mean_time',
 'bid_ask_diff_wap2_ratio_mean_300_min_time',
 'market_cap_volume_sum_min_time',
 'volume_imbalance_min',
 'real_vol2_300_min_time',
 'OB_wap1_dollar_change_abs_sum_300_mean_time_kmn7',
 'market_cap_volume_sum_300_min_time',
 'price_spread_sum_mean_stock',
 'volume_imbalance_min_400',
 'OB_wap1_dollar_change_abs_sum_300_min_time_kmn7',
 'real_vol1_300_min_time_kmn7',
 'wap1_std',
 'market_cap_volume_sum_mean_time',
 'price_spread_sum_300_min_time',
 'bid_ask_diff_wap2_ratio_mean_min_time',
 'spread2_max_400',
 'time_num_seconds_norm_300_std_time',
 'time_num_seconds_norm_min_time',
 'bid_ask_diff_wap2_ratio_mean_mean_time',
 'spread2_max_500',
 'real_vol3_min_time_kmn7',
 'market_cap_volume_sum_300_mean_time',
 'wap1_std_mean_stock',
 'bid_ask_diff_wap2_ratio_mean',
 'real_vol4_std_time',
 'real_vol3_300_min_time',
 'bid_ask_spread_max_300',
 'real_vol1_min_stock',
 'bid_ask_spread_max_400',
 'OB_wap1_dollar_change_abs_sum_300_mean_time_hbd',
 'real_vol2_min_time_hbd',
 'real_vol2_min_time_kmn7',
 'real_vol2_400',
 'real_vol2_std_time',
 'spread2_max',
 'real_vol3_300_min_time_kmn7',
 'bid_ask_diff_wap2_ratio_mean_std_time',
 'bid_ask_spread_max_500',
 'real_vol1_300',
 'wap1_std_300_mean_time',
 'real_vol2_min_stock',
 'OB_wap1_dollar_change_abs_sum_std_time',
 'OB_wap1_dollar_change_abs_sum_std_stock',
 'time_num_seconds_norm_300_min_time',
 'real_vol2_300',
 'market_cap_volume_sum_300_mean_stock',
 'volume_imbalance_min_500',
 'OB_wap1_dollar_change_abs_sum_mean_time_kmn7',
 'price_spread_sum_300_min_time_eqtyp',
 'bid_ask_diff_wap2_ratio_mean_300_mean_time',
 'real_vol2_300_min_time_eqtyp',
 'market_cap_volume_max',
 'real_vol1_500',
 'real_vol2_300_min_time_kmn7',
 'OB_wap1_MA10_MA20_num_cross_300_std_time',
 'spread_max_500',
 'price_spread_sum_300_max_time',
 'market_cap_volume_sum_std_time',
 'real_vol4_300_min_time',
 'real_vol1_300_min_time',
 'spread2_max_300',
 'wap1_std_std_time',
 'real_vol1_400',
 'OB_wap1_MA10_MA20_num_cross_std_time',
 'total_volume_max_400',
 'price_spread_sum_std_stock',
 'OB_wap1_dollar_change_abs_sum_300_mean_time',
 'real_vol1_min_time_kmn7',
 'market_cap_volume_sum_300_max_time',
 'real_vol4_min_stock',
 'wap1_std_300_std_time',
 'price_spread_sum_300_mean_time',
 'wapbal_sum_400',
 'OB_wap1_dollar_change_abs_sum_min_time',
 'volume_imbalance_min_300',
 'OB_wap1_MA10_MA20_num_cross_300_mean_time',
 'real_vol1_std_stock',
 'OB_wap1_dollar_change_abs_sum_max_time',
 'bid_ask_spread_max',
 'market_cap_volume_sum_max_time',
 'wap1_std_300_min_time',
 'bid_ask_diff_wap2_ratio_mean_500',
 'bid_ask_diff_wap2_ratio_mean_300_std_time',
 'real_vol3_std_time',
 'bid_ask_diff_wap2_ratio_mean_300',
 'price_spread_sum_max_time',
 'OB_wap1_MA10_MA20_num_cross_min_time',
 'real_vol1_min_time',
 'bid_ask_diff_wap2_ratio_mean_300_max_time',
 'real_vol3_min_time',
 'real_vol1_std_time',
 'real_vol4_max_time',
 'wap1_std_max_time',
 'market_cap_volume_sum_300_std_time',
 'OB_wap1_dollar_change_abs_sum_300_min_time',
 'wap1_std_300_mean_time_kmn7',
 'real_vol4_mean_time',
 'real_vol1_300_mean_time',
 'price_spread_sum_mean_time',
 'wap1_std_mean_time',
 'real_vol3_300_min_time_eqtyp',
 'bid_ask_diff_wap2_ratio_mean_max_time',
 'real_vol2_min_time',
 'real_vol1_min_time_hbd',
 'wap1_std_300_max_time',
 'real_vol3_300_std_time',
 'OB_wap1_dollar_change_abs_sum_min_stock',
 'bid_ask_diff_wap2_ratio_mean_300_min_time_eqtyp',
 'real_vol2_mean_time_kmn7',
 'real_vol3_std_stock',
 'total_volume_max_300',
 'spread_max']


pickle_dump("./illiCols.pkl", illiCols)

# %%
public1Cols = ['log_return1_realized_volatility',
 'log_return1_realized_volatility_100',
 'log_return1_realized_volatility_200',
 'log_return4_realized_volatility',
 'log_return1_realized_volatility_300',
 'log_return2_realized_volatility',
 'log_return2_realized_volatility_100',
 'log_return4_realized_volatility_200',
 'log_return2_realized_volatility_300',
 'log_return2_realized_volatility_200',
 'log_return3_realized_volatility_200',
 'log_return2_realized_volatility_400',
 'size_tau2_1c1',
 'price_spread2_amax',
 'size_tau2_3c1',
 'log_return4_realized_volatility_300',
 'bid_spread_sum_4c1',
 'price_spread_sum',
 'log_return4_realized_volatility_100',
 'size_tau2_4c1',
 'wap_balance_sum',
 'bid_ask_spread_amax',
 'log_return2_realized_volatility_300_min_time',
 'ask_spread_sum_4c1',
 'log_return1_realized_volatility_400',
 'bid_ask_spread_sum_4c1',
 'log_return2_realized_volatility_500',
 'trade_log_return_realized_volatility_400',
 'log_return3_realized_volatility',
 'log_return1_realized_volatility_400_mean_stock',
 'log_return4_realized_volatility_400',
 'trade_log_return_realized_volatility_std_time',
 'log_return1_realized_volatility_500',
 'trade_log_return_realized_volatility',
 'size_tau2_0c1',
 'log_return2_realized_volatility_min_time',
 'log_return1_realized_volatility_min_stock',
 'trade_log_return_realized_volatility_500',
 'trade_log_return_realized_volatility_400_mean_stock',
 'log_return3_realized_volatility_400',
 'trade_log_return_realized_volatility_mean_stock',
 'trade_order_count_sum_4c1',
 'bid_spread_amax',
 'log_return2_realized_volatility_400_min_time',
 'log_return1_realized_volatility_200_mean_stock',
 'log_return1_realized_volatility_300_mean_stock',
 'log_return2_realized_volatility_200_min_time',
 'price_spread2_sum',
 'trade_log_return_realized_volatility_200_mean_stock',
 'ask_spread_amax',
 'total_volume_sum_0c1',
 'trade_log_return_realized_volatility_400_mean_time',
 'log_return3_realized_volatility_300',
 'log_return2_realized_volatility_std_time',
 'log_return3_realized_volatility_500',
 'trade_log_return_realized_volatility_300_mean_stock',
 'log_return1_realized_volatility_mean_stock',
 'total_volume_sum_1c1',
 'total_volume_sum_0c1/trade_size_sum_0c1',
 'size_tau2_6c1',
 'trade_order_count_sum_3c1',
 'log_return1_realized_volatility_min_time',
 'price_spread_sum_6c1',
 'log_return4_realized_volatility_500',
 'total_volume_sum_1c1/size_tau2_1c1',
 'price_spread_sum_4c1',
 'log_return1_realized_volatility_200_min_stock',
 'price_spread_amax',
 'trade_log_return_realized_volatility_100',
 'trade_order_count_sum_6c1',
 'volume_imbalance_sum_0c1',
 'total_volume_sum_3c1',
 'log_return1_realized_volatility_300_min_stock',
 'trade_size_sum_6c1',
 'trade_size_amax',
 'total_volume_sum_4c1',
 'trade_size_sum_3c1',
 'trade_size_sum_0c1',
 'log_return2_realized_volatility_400_mean_stock',
 'trade_log_return_realized_volatility_300',
 'volume_imbalance_sum_1c1',
 'trade_size_sum_4c1',
 'trade_order_count_sum_1c1',
 'total_volume_sum_3c1/size_tau2_3c1',
 'volume_imbalance_sum_3c1',
 'volume_imbalance_sum_6c1',
 'bid_spread_sum_1c1',
 'log_return1_realized_volatility_200_min_time',
 'trade_order_count_sum_0c1',
 'bid_ask_spread_sum_6c1',
 'bid_spread_sum_6c1',
 'log_return1_realized_volatility_std_time',
 'trade_log_return_realized_volatility_300_min_time',
 'log_return1_realized_volatility_3c1',
 'trade_log_return_realized_volatility_400_min_time',
 'log_return1_realized_volatility_400_mean_time',
 'volume_imbalance_sum_4c1',
 'trade_log_return_realized_volatility_200_min_time',
 'ask_spread_sum_6c1',
 'trade_size_sum_1c1',
 'log_return1_realized_volatility_400_min_time',
 'price_spread_sum_3c1',
 'price_spread_sum_0c1',
 'bid_ask_spread_sum',
 'log_return1_realized_volatility_300_min_time',
 'trade_log_return_realized_volatility_200_std_time',
 'total_volume_sum_6c1',
 'trade_amount_amax',
 'log_return1_realized_volatility_6c1',
 'log_return1_realized_volatility_4c1',
 'trade_log_return_realized_volatility_mean_time',
 'log_return1_realized_volatility_0c1',
 'ask_spread_sum_3c1',
 'trade_df_min',
 'trade_log_return_realized_volatility_200',
 'trade_log_return_realized_volatility_300_mean_time',
 'bid_spread_sum_0c1',
 'log_return2_realized_volatility_min_stock',
 'log_return3_realized_volatility_100',
 'trade_log_return_realized_volatility_400_max_time',
 'ask_spread_sum_0c1',
 'log_return2_realized_volatility_400_mean_time',
 'log_return2_realized_volatility_200_mean_stock',
 'trade_log_return_realized_volatility_300_std_time',
 'log_return1_realized_volatility_1c1',
 'bid_ask_spread_sum_0c1',
 'log_return2_realized_volatility_300_mean_stock',
 'log_return1_realized_volatility_max_time']

pickle_dump("./public1Cols.pkl", public1Cols)
